# %%
import pandas as pd
import numpy as np
import itertools
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import roc_auc_score
from tqdm import tqdm

# %% [markdown]
# ### AKI

# %%
from blood_panel_data_preprocessing import blood_panel_data, aki_data, sepsis_data

# %%
index, data, block, cost = aki_data()

# %%
from data_loader import Data_Loader
data_loader = Data_Loader(data, block, test_ratio = 0.2, val_ratio = 0.2, index= index)

# %%
X_train = data_loader.train[:,:-1]
X_test = data_loader.test[:,:-1]
X_val = data_loader.val[:,:-1]

y_train = data_loader.train[:,-1]
y_test = data_loader.test[:,-1]
y_val = data_loader.val[:,-1]

# %%
from sklearn.ensemble import RandomForestClassifier
n_estimators =  np.linspace(20,620,11,dtype=int)
max_depths = [3,7,11,21,31,61]
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(n_estimators, max_depth))):
    clf = RandomForestClassifier(class_weight='balanced',n_estimators = hp1, max_depth = hp2 )
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/RFAKI.csv')
# Out:
# 100%|███████████████████████████████████████████| 66/66 [11:11<00:00, 10.18s/it]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1   hp2    val_f1   val_auc   test_f1  test_auc  test_prec  \
# 8    80.0  11.0  0.504432  0.785962  0.439320  0.763929   0.418014
# 2    20.0  11.0  0.500406  0.781915  0.416157  0.756495   0.399061
# 26  260.0  11.0  0.500402  0.792163  0.454321  0.775117   0.439141
# 37  380.0   7.0  0.499345  0.790910  0.452611  0.770829   0.363919
# 13  140.0   7.0  0.499343  0.789083  0.453307  0.770194   0.365777
#
#     test_recall
# 8      0.462916
# 2      0.434783
# 26     0.470588
# 37     0.598465
# 13     0.595908

# %%
from sklearn.linear_model import LogisticRegression
C =  [0.0001,0.001,0.1,1,10,100]
penalty = ['l1', 'l2', 'elasticnet', 'none']
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(C, penalty))):
    clf = LogisticRegression(class_weight='balanced',C = hp1, penalty = hp2, solver='saga', max_iter=1000, l1_ratio=0.5)
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/LRAKI.csv')

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1         hp2    val_f1   val_auc   test_f1  test_auc  test_prec  \
# 12    1.0          l1  0.474725  0.798561  0.452303  0.797081   0.333333
# 11    0.1        none  0.474725  0.798619  0.452675  0.797155   0.333738
# 22  100.0  elasticnet  0.474725  0.798620  0.452675  0.797153   0.333738
# 21  100.0          l2  0.474725  0.798623  0.452675  0.797157   0.333738
# 20  100.0          l1  0.474725  0.798618  0.452675  0.797149   0.333738
#
#     test_recall
# 12     0.703325
# 11     0.703325
# 22     0.703325
# 21     0.703325
# 20     0.703325

# %%
from xgboost import XGBClassifier
n_estimators =  np.linspace(20,620,11,dtype=int)
max_depths = [3,7,11,21,31,61]
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(n_estimators, max_depth))):
    clf = XGBClassifier(n_estimators = hp1, max_depth = hp2 )
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/XGAKI.csv')
# Out:
# 100%|███████████████████████████████████████████| 66/66 [05:11<00:00,  4.72s/it]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1  hp2    val_f1   val_auc   test_f1  test_auc  test_prec  test_recall
# 42  440.0  3.0  0.440567  0.786340  0.404605  0.784796   0.566820     0.314578
# 48  500.0  3.0  0.436681  0.784338  0.411862  0.783264   0.578704     0.319693
# 36  380.0  3.0  0.436205  0.787949  0.422259  0.784493   0.586364     0.329923
# 30  320.0  3.0  0.428256  0.788449  0.413223  0.788339   0.584112     0.319693
# 7    80.0  7.0  0.426667  0.777801  0.391003  0.766269   0.604278     0.289003

# %%
from lightgbm import LGBMClassifier
n_estimators =  np.linspace(20,620,11,dtype=int)
max_depths = [3,7,11,21,31,61]
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(n_estimators, max_depth))):
    clf = LGBMClassifier(n_estimators = hp1, max_depth = hp2, class_weight= 'balanced' )
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/LGAKI.csv')
# Out:
# 100%|███████████████████████████████████████████| 66/66 [00:57<00:00,  1.16it/s]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1   hp2    val_f1   val_auc   test_f1  test_auc  test_prec  \
# 41  380.0  61.0  0.523577  0.790138  0.474453  0.789645   0.452436
# 40  380.0  31.0  0.523577  0.790138  0.474453  0.789645   0.452436
# 39  380.0  21.0  0.523577  0.790138  0.474453  0.789645   0.452436
# 38  380.0  11.0  0.523002  0.794636  0.472906  0.787020   0.456057
# 44  440.0  11.0  0.522314  0.791650  0.465823  0.783818   0.461153
#
#     test_recall
# 41     0.498721
# 40     0.498721
# 39     0.498721
# 38     0.491049
# 44     0.470588

# %% [markdown]
# ### Sepsis

# %%
from blood_panel_data_preprocessing import blood_panel_data, aki_data, sepsis_data

# %%
data, block, cost = sepsis_data()

# %%
from data_loader import Data_Loader
data_loader = Data_Loader(data, block, test_ratio = 0.2, val_ratio = 0.2)

# %%
X_train = data_loader.train[:,:-1]
X_test = data_loader.test[:,:-1]
X_val = data_loader.val[:,:-1]

y_train = data_loader.train[:,-1]
y_test = data_loader.test[:,-1]
y_val = data_loader.val[:,-1]

# %%
from sklearn.ensemble import RandomForestClassifier
n_estimators =  np.linspace(20,620,11,dtype=int)
max_depths = [3,7,11,21,31,61]
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(n_estimators, max_depth))):
    clf = RandomForestClassifier(class_weight='balanced',n_estimators = hp1, max_depth = hp2 )
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/RFSepsis.csv')
# Out:
# 100%|███████████████████████████████████████████| 66/66 [02:39<00:00,  2.42s/it]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1  hp2    val_f1   val_auc   test_f1  test_auc  test_prec  test_recall
# 6    80.0  3.0  0.437908  0.766100  0.456140  0.800963   0.374101     0.584270
# 18  200.0  3.0  0.422442  0.759139  0.480349  0.809310   0.392857     0.617978
# 61  620.0  7.0  0.421525  0.788380  0.423077  0.830291   0.492537     0.370787
# 31  320.0  7.0  0.416667  0.790831  0.389610  0.830887   0.461538     0.337079
# 36  380.0  3.0  0.410774  0.765872  0.477477  0.806856   0.398496     0.595506

# %%
from sklearn.linear_model import LogisticRegression
C =  [0.0001,0.001,0.1,1,10,100]
penalty = ['l1', 'l2', 'elasticnet', 'none']
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(C, penalty))):
    clf = LogisticRegression(class_weight='balanced',C = hp1, penalty = hp2, solver='saga', max_iter=1000, l1_ratio=0.5)
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/LRSepsis.csv')
# Out:
#   0%|                                                    | 0/24 [00:00<?, ?it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#   8%|███▋                                        | 2/24 [00:00<00:01, 18.01it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
#  17%|███████▎                                    | 4/24 [00:00<00:01, 17.37it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  25%|███████████                                 | 6/24 [00:00<00:00, 18.00it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
#  33%|██████████████▋                             | 8/24 [00:00<00:01, 15.63it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  42%|█████████████████▉                         | 10/24 [00:00<00:00, 14.29it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
#  50%|█████████████████████▌                     | 12/24 [00:00<00:00, 12.80it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  58%|█████████████████████████                  | 14/24 [00:01<00:00, 12.66it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  67%|████████████████████████████▋              | 16/24 [00:01<00:00, 12.46it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  75%|████████████████████████████████▎          | 18/24 [00:01<00:00, 12.37it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
#  83%|███████████████████████████████████▊       | 20/24 [00:01<00:00, 11.85it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  92%|███████████████████████████████████████▍   | 22/24 [00:01<00:00, 11.80it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# 100%|███████████████████████████████████████████| 24/24 [00:01<00:00, 12.64it/s]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1         hp2    val_f1   val_auc   test_f1  test_auc  test_prec  \
# 10    0.1  elasticnet  0.455882  0.790852  0.505929  0.824994   0.390244
# 12    1.0          l1  0.455206  0.791390  0.505929  0.823848   0.390244
# 13    1.0          l2  0.455206  0.791566  0.498024  0.823137   0.384146
# 22  100.0  elasticnet  0.455206  0.791514  0.498024  0.822885   0.384146
# 21  100.0          l2  0.455206  0.791493  0.498024  0.822908   0.384146
#
#     test_recall
# 10     0.719101
# 12     0.719101
# 13     0.707865
# 22     0.707865
# 21     0.707865

# %%
from xgboost import XGBClassifier
n_estimators =  np.linspace(20,620,11,dtype=int)
max_depths = [3,7,11,21,31,61]
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(n_estimators, max_depth))):
    clf = XGBClassifier(n_estimators = hp1, max_depth = hp2 )
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/XGSepsis.csv')
# Out:
# 100%|███████████████████████████████████████████| 66/66 [01:45<00:00,  1.60s/it]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1  hp2    val_f1   val_auc   test_f1  test_auc  test_prec  test_recall
# 24  260.0  3.0  0.373737  0.781636  0.430769  0.827540   0.682927     0.314607
# 12  140.0  3.0  0.369231  0.790904  0.459259  0.829466   0.673913     0.348315
# 6    80.0  3.0  0.366492  0.799561  0.390625  0.832653   0.641026     0.280899
# 18  200.0  3.0  0.336842  0.783022  0.466165  0.825843   0.704545     0.348315
# 60  620.0  3.0  0.336634  0.770217  0.415385  0.825086   0.658537     0.303371

# %%
from lightgbm import LGBMClassifier
n_estimators =  np.linspace(20,620,11,dtype=int)
max_depths = [3,7,11,21,31,61]
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(n_estimators, max_depth))):
    clf = LGBMClassifier(n_estimators = hp1, max_depth = hp2, class_weight= 'balanced' )
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/LGSepsis.csv')
# Out:
# 100%|███████████████████████████████████████████| 66/66 [00:41<00:00,  1.59it/s]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1  hp2    val_f1   val_auc   test_f1  test_auc  test_prec  test_recall
# 6    80.0  3.0  0.464183  0.778523  0.500000  0.843729   0.410072     0.640449
# 18  200.0  3.0  0.463415  0.778957  0.502415  0.846549   0.440678     0.584270
# 12  140.0  3.0  0.461538  0.780695  0.497696  0.846595   0.421875     0.606742
# 24  260.0  3.0  0.461538  0.776723  0.525253  0.842055   0.477064     0.584270
# 30  320.0  3.0  0.441558  0.775792  0.529101  0.841023   0.500000     0.561798

# %% [markdown]
# ### BP

# %%
data, block, cost = blood_panel_data()

# %%
from data_loader import Data_Loader
data_loader = Data_Loader(data, block, test_ratio = 0.2, val_ratio = 0.2)

# %%
X_train = data_loader.train[:,:-1]
X_test = data_loader.test[:,:-1]
X_val = data_loader.val[:,:-1]

y_train = data_loader.train[:,-1]
y_test = data_loader.test[:,-1]
y_val = data_loader.val[:,-1]

# %%
from sklearn.ensemble import RandomForestClassifier
n_estimators =  np.linspace(20,620,11,dtype=int)
max_depths = [3,7,11,21,31,61]
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(n_estimators, max_depth))):
    clf = RandomForestClassifier(class_weight='balanced',n_estimators = hp1, max_depth = hp2 )
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/RFBP.csv')
# Out:
# 100%|███████████████████████████████████████████| 66/66 [23:54<00:00, 21.74s/it]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1   hp2    val_f1   val_auc   test_f1  test_auc  test_prec  \
# 32  320.0  11.0  0.649046  0.945845  0.595059  0.937782   0.515829
# 14  140.0  11.0  0.646628  0.946550  0.604502  0.938462   0.523191
# 50  500.0  11.0  0.644543  0.946376  0.596567  0.937597   0.516729
# 38  380.0  11.0  0.641537  0.945990  0.593383  0.937345   0.511971
# 20  200.0  11.0  0.640408  0.945425  0.603854  0.937120   0.522222
#
#     test_recall
# 32     0.703046
# 14     0.715736
# 50     0.705584
# 38     0.705584
# 20     0.715736

# %%
from sklearn.linear_model import LogisticRegression
C =  [0.0001,0.001,0.1,1,10,100]
penalty = ['l1', 'l2', 'elasticnet', 'none']
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(C, penalty))):
    clf = LogisticRegression(class_weight='balanced',C = hp1, penalty = hp2, solver='saga', max_iter=1000, l1_ratio=0.5)
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/LRBP.csv')
# Out:
#   0%|                                                    | 0/24 [00:00<?, ?it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#   4%|█▊                                          | 1/24 [00:00<00:16,  1.37it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  12%|█████▌                                      | 3/24 [00:01<00:13,  1.59it/s]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  17%|███████▎                                    | 4/24 [00:25<02:31,  7.59s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  21%|█████████▏                                  | 5/24 [00:26<01:43,  5.47s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  29%|████████████▊                               | 7/24 [00:26<00:49,  2.90s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  33%|██████████████▋                             | 8/24 [00:50<02:26,  9.18s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  38%|████████████████▌                           | 9/24 [00:54<01:52,  7.49s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  46%|███████████████████▋                       | 11/24 [01:00<01:08,  5.27s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  50%|█████████████████████▌                     | 12/24 [01:24<02:10, 10.87s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  54%|███████████████████████▎                   | 13/24 [01:39<02:13, 12.17s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  62%|██████████████████████████▉                | 15/24 [02:03<01:47, 12.00s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  67%|████████████████████████████▋              | 16/24 [02:27<02:05, 15.63s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  71%|██████████████████████████████▍            | 17/24 [02:53<02:11, 18.80s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
#  75%|████████████████████████████████▎          | 18/24 [03:15<01:58, 19.79s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  79%|██████████████████████████████████         | 19/24 [03:42<01:48, 21.80s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  83%|███████████████████████████████████▊       | 20/24 [04:06<01:29, 22.40s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  88%|█████████████████████████████████████▋     | 21/24 [04:32<01:11, 23.67s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  92%|███████████████████████████████████████▍   | 22/24 [04:56<00:47, 23.72s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#  96%|█████████████████████████████████████████▏ | 23/24 [05:23<00:24, 24.57s/it]/home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1317: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/ylo7832/.conda/envs/bertenv/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 100%|███████████████████████████████████████████| 24/24 [05:46<00:00, 14.46s/it]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#      hp1         hp2    val_f1   val_auc   test_f1  test_auc  test_prec  \
# 12   1.0          l1  0.561497  0.938746  0.537500  0.934131   0.388262
# 10   0.1  elasticnet  0.561497  0.939356  0.539484  0.934505   0.389831
# 14   1.0  elasticnet  0.561197  0.938878  0.538763  0.934058   0.389581
# 18  10.0  elasticnet  0.561159  0.938319  0.535938  0.933115   0.387133
# 13   1.0          l2  0.560897  0.938913  0.538341  0.933983   0.389140
#
#     test_recall
# 12     0.873096
# 10     0.875635
# 14     0.873096
# 18     0.870558
# 13     0.873096

# %%
from xgboost import XGBClassifier
n_estimators =  np.linspace(20,620,11,dtype=int)
max_depths = [3,7,11,21,31,61]
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(n_estimators, max_depth))):
    clf = XGBClassifier(n_estimators = hp1, max_depth = hp2 )
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/XGBP.csv')
# Out:
# 100%|███████████████████████████████████████████| 66/66 [06:47<00:00,  6.18s/it]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1   hp2    val_f1   val_auc   test_f1  test_auc  test_prec  \
# 37  380.0   7.0  0.617188  0.948749  0.617143  0.938080   0.705882
# 41  380.0  61.0  0.616290  0.950904  0.620290  0.944410   0.722973
# 40  380.0  31.0  0.616290  0.950904  0.620290  0.944410   0.722973
# 49  500.0   7.0  0.614786  0.948335  0.606581  0.938363   0.695082
# 61  620.0   7.0  0.613437  0.947937  0.605452  0.938191   0.696370
#
#     test_recall
# 37     0.548223
# 41     0.543147
# 40     0.543147
# 49     0.538071
# 61     0.535533

# %%
from lightgbm import LGBMClassifier
n_estimators =  np.linspace(20,620,11,dtype=int)
max_depths = [3,7,11,21,31,61]
results = pd.DataFrame(columns = ['hp1','hp2', 'val_f1', 'val_auc', 'test_f1','test_auc', 'test_prec', 'test_recall'])
i = 0
for hp1, hp2 in tqdm(list(itertools.product(n_estimators, max_depth))):
    clf = LGBMClassifier(n_estimators = hp1, max_depth = hp2, class_weight= 'balanced' )
    clf.fit(X_train, y_train)
    y_hat_val = clf.predict_proba(X_val)[:,1]
    y_hat_test = clf.predict_proba(X_test)[:,1]
    results.loc[i] = [hp1, hp2,
                       precision_recall_fscore_support(y_val, y_hat_val > 0.5,average='binary')[2],
                       roc_auc_score(y_val, y_hat_val),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[2],
                       roc_auc_score(y_test, y_hat_test),
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[0],
                       precision_recall_fscore_support(y_test, y_hat_test > 0.5,average='binary')[1]
                      ]
    i+=1
results.to_csv('/home/ylo7832/Blood_Panel-master/baseline/LGBP.csv')
# Out:
# 100%|███████████████████████████████████████████| 66/66 [01:17<00:00,  1.17s/it]

# %%
results.sort_values('val_f1', ascending=False).head()
# Out:
#       hp1   hp2    val_f1   val_auc   test_f1  test_auc  test_prec  \
# 38  380.0  11.0  0.675266  0.952017  0.626932  0.940576   0.554688
# 31  320.0   7.0  0.672071  0.947787  0.627282  0.943151   0.543762
# 61  620.0   7.0  0.671010  0.947281  0.636472  0.942239   0.600000
# 56  560.0  11.0  0.669348  0.952441  0.631829  0.942014   0.593750
# 32  320.0  11.0  0.669118  0.951881  0.625806  0.941327   0.542910
#
#     test_recall
# 38     0.720812
# 31     0.741117
# 61     0.677665
# 56     0.675127
# 32     0.738579
